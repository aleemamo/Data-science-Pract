# %%
"Overview"
'In this notebook, I am learning how to open my excel file in python jupyter note'
# Out:
# 'In this notebook, I am learning how to open my excel file in python jupyter note'

# %%
import pandas as pd
import numpy as np

# %%
example_table=pd.read_excel('check_loan.xlsx')

# %%
example_table
# Out:
#       Unnamed: 0    ID  Age  Experience  Income  ZIP Code  Family  CCAvg  \
# 0              0     1   25           1      49     91107       4    1.6
# 1              1     2   45          19      34     90089       3    1.5
# 2              2     3   39          15      11     94720       1    1.0
# 3              3     4   35           9     100     94112       1    2.7
# 4              4     5   35           8      45     91330       4    1.0
# ...          ...   ...  ...         ...     ...       ...     ...    ...
# 4995        4995  4996   29           3      40     92697       1    1.9
# 4996        4996  4997   30           4      15     92037       4    0.4
# 4997        4997  4998   63          39      24     93023       2    0.3
# 4998        4998  4999   65          40      49     90034       3    0.5
# 4999        4999  5000   28           4      83     92612       3    0.8
#
#       Education  Mortgage  Securities Account  CD Account  Online  CreditCard  \
# ...

# %%
### strings
name="Moruf"

# %%
print(name)
# Out:
# Moruf

# %%
salute="Hello World!"

# %%
print(salute)
# Out:
# Hello World!

# %%
### variables
name="Moruf"
greet="Hello,World!"

# %%
print(name)
print(name,greet)
# Out:
# Moruf
# Moruf Hello,World!
